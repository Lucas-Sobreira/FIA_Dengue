# %% [markdown]
# ### Verificando os arquivos

# %%
display(dbutils.fs.ls("/FileStore/tables"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(dbutils.fs.ls("/FileStore/projeto"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ### Blob Storage

# %% [markdown]
# #### Salvando os Dados

# %%
# dbfs:/FileStore/tables/municipios_dengue_2011.csv

# dbfs:/FileStore/tables/municipio_agua_esgoto.csv
# dbfs:/FileStore/tables/municipio_2010_2020.csv

agua_esgoto = spark.read.csv('/FileStore/tables/municipio_agua_esgoto.csv', header=True, inferSchema=True, sep=',')
municipio_2010_2020 = spark.read.csv('/FileStore/tables/municipio_2010_2020.csv', header=True, inferSchema=True, sep=',')

# dengue_municipio_2011 = spark.read.csv('/FileStore/tables/municipios_dengue_2011.csv', header=True, inferSchema=True, sep=',')
# dengue_municipio_2012 = spark.read.csv('/FileStore/tables/municipios_dengue_2012.csv', header=True, inferSchema=True, sep=',')
# dengue_municipio_2013 = spark.read.csv('/FileStore/tables/municipios_dengue_2013.csv', header=True, inferSchema=True, sep=',')
# dengue_municipio_2014 = spark.read.csv('/FileStore/tables/municipios_dengue_2014.csv', header=True, inferSchema=True, sep=',')

# dengue_municipio_2015 = spark.read.csv('/FileStore/tables/municipio_dengue_2015.csv', header=True, inferSchema=True, sep=',')

# dengue_municipio_2016 = spark.read.csv('/FileStore/tables/municipios_dengue_2016.csv', header=True, inferSchema=True, sep=',')
# dengue_municipio_2017 = spark.read.csv('/FileStore/tables/municipios_dengue_2017.csv', header=True, inferSchema=True, sep=',')

# dengue_municipio_2018 = spark.read.csv('/FileStore/tables/dengue_municipio_2018.csv', header=True, inferSchema=True, sep=',')
# dengue_municipio_2019 = spark.read.csv('/FileStore/tables/dengue_municipio_2019.csv', header=True, inferSchema=True, sep=',')
# dengue_municipio_2020 = spark.read.csv('/FileStore/tables/dengue_municipio_2020.csv', header=True, inferSchema=True, sep=',')
# dengue_municipio_2021 = spark.read.csv('/FileStore/tables/dengue_municipio_2021.csv', header=True, inferSchema=True, sep=',')

# %%
STORAGE_ACCOUNT = 'aulafiaead'
CONTAINER = 'grupo2'
BLOB_STORAGE_KEY = 'QDKbVST0U3yAaEI4HN9DFwYTB3jGO6xb4Kk5r59UFYOzXrkrVLESZKmrKzPZ/eEsDLV8Fw5XxybA+ASt4EZ2zA=='

spark.conf.set(f"fs.azure.account.key.{STORAGE_ACCOUNT}.blob.core.windows.net", BLOB_STORAGE_KEY)

# Escrita de Dados

agua_esgoto.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/agua_esgoto')
municipio_2010_2020.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/pib_2010_2020')

# dengue_municipio_2011.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2011')
# dengue_municipio_2012.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2012')
# dengue_municipio_2013.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2013')
# dengue_municipio_2014.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2014')

# dengue_municipio_2015.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2015')
# dengue_municipio_2016.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2016')
# dengue_municipio_2017.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2017')

# dengue_municipio_2018.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2018')
# dengue_municipio_2019.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2019')
# dengue_municipio_2020.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2020')
# dengue_municipio_2021.write.format('delta').option("mergeSchema", "true").mode('overwrite').save(f'wasbs://{CONTAINER}@{STORAGE_ACCOUNT}.blob.core.windows.net/raw/2021')
